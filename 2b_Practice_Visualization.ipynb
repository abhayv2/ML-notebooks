# %% [markdown]
# # Lecture 2 Visualization

# %%
import numpy as np
import pandas as pd  # for data analytics

# The two packages below are for plotting
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
# Type it in the first cell of your notebook, then your matplotlib plots will be included next to your codes. 
# Otherwise, include plt.show()

# %% [markdown]
# ## 1. Data Loading and Cleaning Basics
#
# To import data from a csv file, use syntax: **pd.read_csv(FILE_NAME)** Make sure the file is under your current directory. You will obtain a Pandas DataFrame (similar to spreadsheet).
#
# - Use **DataFrame.head(k)** to see the first k rows of our data.
# - Use **DataFrame.shape** to collect the dimensions.
# - Use **DataFrame.columns** to collect the column names

# %% [markdown]
# **Practice**
# - Use Pandas package to load the csv file: train.csv
# - View the first 10 rows of the dataset.
# - Report the number of observations and number of variables.
# - Report all the variable names.

# %%
# data loading
df = pd.read_csv('train.csv')

# %%
# first several rows
df.head(10)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
# shape of the dataframe
df.shape
# Out:
# (1460, 81)

# %%
# variable names
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %% [markdown]
# ### 1.1 Handling Anomaly
# - Use **Dataframe.drop_duplicates()** to keep only unique records.
# - Use **DataFrame.dropna()**: to drop missing value
#     - By default, drop rows with any missing value
#     - axis: default = 'index' (i.e., drop rows). If you want to drop columns with any missing, = 'columns'

# %%
# drop duplicates
df = df.drop_duplicates() # no duplications
# df

# %%
# Drop variables with missing values

## drop VARIABLES: axis = columns or 1; for row, index or 0
## df.dropna(axis = 'columns')
df.dropna(axis = 1)
# Out:
#         Id  MSSubClass MSZoning  LotArea Street LotShape LandContour  \
# 0        1          60       RL     8450   Pave      Reg         Lvl
# 1        2          20       RL     9600   Pave      Reg         Lvl
# 2        3          60       RL    11250   Pave      IR1         Lvl
# 3        4          70       RL     9550   Pave      IR1         Lvl
# 4        5          60       RL    14260   Pave      IR1         Lvl
# ...    ...         ...      ...      ...    ...      ...         ...
# 1455  1456          60       RL     7917   Pave      Reg         Lvl
# 1456  1457          20       RL    13175   Pave      Reg         Lvl
# 1457  1458          70       RL     9042   Pave      Reg         Lvl
# 1458  1459          20       RL     9717   Pave      Reg         Lvl
# 1459  1460          20       RL     9937   Pave      Reg         Lvl
#
#      Utilities LotConfig LandSlope  ... EnclosedPorch 3SsnPorch ScreenPorch  \
# ...

# %% [markdown]
# ### 1.2 Understanding Pandas DataFrame

# %% [markdown]
# In this section, we focus on indexing and subsampling of a pandas dataframe. This helps with calculation and advanced visualization in upcoming sections.
#
# One advantage of using Pandas DataFrame is to obtain columns (in pandas, a 'Series') easily through "[ ]" operator.
# - To obtain one variable, use: **DataFrame[var_name]**
# - To obtain multiple variables, use: **DataFrame[var_list]**, where var_list = [var1, var2, ...]

# %%
# Selecting one/multiple columns through [] operator

var = ['SalePrice','OverallQual','GrLivArea','GarageCars','TotalBsmtSF']

df[  ['SalePrice', 'OverallQual']   ]

df[var]
# Out:
#       SalePrice  OverallQual  GrLivArea  GarageCars  TotalBsmtSF
# 0        208500            7       1710           2          856
# 1        181500            6       1262           2         1262
# 2        223500            7       1786           2          920
# 3        140000            7       1717           3          756
# 4        250000            8       2198           3         1145
# ...         ...          ...        ...         ...          ...
# 1455     175000            6       1647           2          953
# 1456     210000            6       2073           2         1542
# 1457     266500            7       2340           1         1152
# 1458     142125            5       1078           1         1078
# 1459     147500            5       1256           1         1256
#
# [1460 rows x 5 columns]

# %% [markdown]
# There are two choices for indexing in a DataFrame.
# - **Integer based indexing.** Works similar to numpy array. **Syntax: DataFrame.iloc[row_range, column_range]**
#     - You can use a list of integers to select separated elements.
# - **Label based indexing.** Extract rows and columns based on corresponding label (e.g., variable name). Syntax: **DataFrame.loc[row_range, column_range]**.
#     - For label indexing, the range is INCLUSIVE!

# %%
# Select rows and columns based on integer indexing. 
# This works the same as 2d arrays.

# First 10 rows, 3 columns, use iloc
df.iloc[ :10  , :3  ]
# Out:
#    Id  MSSubClass MSZoning
# 0   1          60       RL
# 1   2          20       RL
# 2   3          60       RL
# 3   4          70       RL
# 4   5          60       RL
# 5   6          50       RL
# 6   7          20       RL
# 7   8          60       RL
# 8   9          50       RM
# 9  10         190       RL

# %%
# Selecing several columns/rows based on label indexing 
# By default, row labels are just integers

df.loc[  :9 , 'Id': 'MSZoning' ]
# Out:
#    Id  MSSubClass MSZoning
# 0   1          60       RL
# 1   2          20       RL
# 2   3          60       RL
# 3   4          70       RL
# 4   5          60       RL
# 5   6          50       RL
# 6   7          20       RL
# 7   8          60       RL
# 8   9          50       RM
# 9  10         190       RL

# %% [markdown]
# ## 2. Univariate Data Analysis
# To obtain summary statistics, use syntax **DataFrame.describe()**:
# - percentiles: the percentiles to report (instead of quantiles). Use a list to specify all percentiles.

# %%
# Obtain summary statistics
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
my_perc = [0.01, 0.5, 0.75, 0.99]

df.describe(percentiles = my_perc)
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 1%       15.590000    20.000000    21.000000    1680.000000     3.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# 99%    1445.410000   190.000000   141.000000   37567.640000    10.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# ...

# %% [markdown]
# ### 2.1 Visualization Basics
# **Labels and Titles**
#
# - Use **plt.xlabel("CONTENT")**, and **plt.ylabel("CONTENT")** to specify the labels. Use **plt.title("TITLE NAME")** to specify the titles.
#
# - Use **plt.xlim(LEFT_LIMIT, RIGHT_LIMIT)** to set range for x axis. Change xlim to ylim for y axis.
#
# - Use **plt.xticks(ticks, labels)** to specify ticks (i.e., what values to include) and **corresponding** labels (i.e., labels of the values). Both should be specified in a list. The length of ticks and labels must match.
#
# - Use **plt.legend([list_of_legends])** to show legend
#
# **Parameter Settings**
#
# The specific parameters differ for different plots. But here are some common parameters.
# - color: color of the lines/bars. 'r', 'g', 'b', 'k' for red, green, blue, and black, correspondingly.
# - alpha: transparency level. 0<alpha<=1; lower value of alpha => more transparent.
# - linestyle: the line style (e.g., solid/dash/...). Solid: -, Dashed: --, Dotted: ., Dash-dot: -.
#
# ### 2.2 Histogram
# We can use syntax: **plt.hist(x)** to create the histogram of x.
# - bins: bin number
#
# To create overlap histogram, we use another package: Seaborn. The syntax is: **sns.histplot(data, x, hue)**. Specify parameter name clearly
# - data: the Pandas DataFrame to use
# - x: the variable name of x (the one for histogram)
# - hue: the variable name of category, if you want to create overlapped histogram by a specific variable.
#     - It must be a variable in the DataFrame.
# For other specifications, check: https://seaborn.pydata.org/generated/seaborn.histplot.html

# %% [markdown]
# **Practice: Histogram**
# - Draw a histogram of 'SalePrice', set bin number as 20. Specify color as red. Label axes accordingly.
# - Draw histogram of two samples: (1) those with OverallQual greater than 6; (2) those with OverallQual less or equal to 6. Overlap the two figures.

# %%
## Histogram with detailed labels
x = df['SalePrice']
plt.hist(x, bins = 20, color = 'r')
plt.xlabel("Sales Price")
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
## Overlaid Histogram (w/ seaborn)

# First, generate a new variable, it takes 1 if quality is high, 0 otherwise

# Draw histogram of two samples: (1) those with OverallQual greater than 6; 
## (2) those with OverallQual less or equal to 6. Overlap the two figures.

high_qual = df['OverallQual'] > 6

# Second, put it to dataframe
df['High_Quality'] = high_qual

# df['High_Quality']
sns.histplot(data = df, x = 'SalePrice', hue = 'High_Quality')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='Count'>

# %% [markdown]
# ### Section 2.3 Boxplot
# Use syntax **plt.boxplot(x)** to create boxplot of x.
#
# It is very tedious to draw a boxplot of different groups using pyplot. This case, use: **sns.boxplot(data, x, y...)**
# - x: If one-dimensional, then represents the variables to plot. If two-dimensional (i.e., box plot of different groups), then represents the group indicator.
# - y: Not available if one-dimensional. If two-dimensional, the variable to plot.
# - orient: = "v" if vertical, ="h" if horizontal
#
# For other specifications: https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# **Practice:**
# - Provide a boxplot of SalePrice
# - Provide a set of boxplots of 'SalePrice' based on different levels of 'OverallQual' (use Seaborn)

# %%
# Boxplot basics

x1 = df['SalePrice']

plt.boxplot(x1)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x27c28598ca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x27c285a93a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x27c28598940>],
#  'medians': [<matplotlib.lines.Line2D at 0x27c285a9a60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x27c285a9dc0>],
#  'means': []}

# %%
# To provide a set of boxplots, it's a lot easier to use seaborn

sns.boxplot(data = df, x = 'OverallQual', y = 'SalePrice')
# Out:
# <AxesSubplot:xlabel='OverallQual', ylabel='SalePrice'>

# %%
# sns.boxplot(data = df, x = 'SalePrice', y = 'OverallQual')
# Out:
# <AxesSubplot:xlabel='SalePrice', ylabel='OverallQual'>

# %% [markdown]
# ## 3. Multivariate Data Analysis
#
# To create correlation matrix, use syntax: **.corr()** Remember that the variables should be specified in a list. Use syntax **sns.heatmap()** to obtain heatmap.
#
# **Practice:**
# - Create a correlation matrix of the following variables: 'SalePrice','OverallQual','GrLivArea','GarageCars','TotalBsmtSF'
# - Use a heatmap to visualize the correlation of the above-mentioned variables

# %%
# Correlation matrix
var = ['SalePrice','OverallQual','GrLivArea','GarageCars','TotalBsmtSF']


my_corr_matrix = df[var].corr()

my_corr_matrix
# Out:
#              SalePrice  OverallQual  GrLivArea  GarageCars  TotalBsmtSF
# SalePrice     1.000000     0.790982   0.708624    0.640409     0.613581
# OverallQual   0.790982     1.000000   0.593007    0.600671     0.537808
# GrLivArea     0.708624     0.593007   1.000000    0.467247     0.454868
# GarageCars    0.640409     0.600671   0.467247    1.000000     0.434585
# TotalBsmtSF   0.613581     0.537808   0.454868    0.434585     1.000000

# %%
# heatmap

sns.heatmap(my_corr_matrix )
# Out:
# <AxesSubplot:>

# %% [markdown]
# Use **plt.scatter(x,y)** to produce a scatter plot. The first entry is horizontal axis, the second entry is vertical entry.

# %% [markdown]
# **Practice**
# - Use scatter plot to explore the relationship between SalePrice and GrLivArea
# - Create a scatter plot to show the relationship between Saleprice and GrLivArea, use different colors to show OverallQual. Set transparency as 0.7

# %%
# Scatter plot basics

x = df['GrLivArea']
y = df['SalePrice']
plt.scatter(x,y) # color: c
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
# Scatter plot with color

x = df['GrLivArea']
y = df['SalePrice']
qual = df['OverallQual']
plt.scatter(x,y, c = qual) # color: c
plt.xlabel('Area')
plt.ylabel('Price')
plt.colorbar()
